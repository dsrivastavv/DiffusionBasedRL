# %%
import os
os.chdir('/root/DiffusionBasedRL')

# %%
# Change This
from config.maze2d_dit import base
config = base['diffusion']

# %%
from loguru import logger
import os
logger.info(os.getcwd())
import sys
logger.info(sys.executable)
sys.path.append(os.getcwd())
import numpy as np

from diffuser.models.dit import LDiT_models

import diffuser.utils as utils


#-----------------------------------------------------------------------------#
#----------------------------------- setup -----------------------------------#
#-----------------------------------------------------------------------------#

class argsmaker:
    # Change this
    dataset: str = 'maze2d-large-v1' #maze2d-large-v1, maze2d-medium-v1, maze2d-umaze-v1
    def __init__(self, inputargs):
        for k, v in inputargs.items():
            setattr(self, k, v)
        # Change logbase, horizon and n_diffusion_steps
        self.logbase = f'logs_dit_final_1M' #logs_dif_UMAZE_1M, logs_dit_final_1M
        self.horizon: int = 384 #384 for large, 256 for medium, 128 for small 
        self.n_diffusion_steps: int = 256 # 256 for large, 256 for medium, 64 for small
        self.savepath = f'{self.logbase}/{self.dataset}/diffusion/H{self.horizon}_T{self.n_diffusion_steps}'

args = argsmaker(config)
# Out:
# 2024-06-07 19:24:15.852 | INFO     | __main__:<module>:3 - /root/DiffusionBasedRL
# 2024-06-07 19:24:15.854 | INFO     | __main__:<module>:5 - /opt/conda/envs/diffuser/bin/python

# %%
#-----------------------------------------------------------------------------#
#---------------------------------- dataset ----------------------------------#
#-----------------------------------------------------------------------------#

dataset_config = utils.Config(
    args.loader,
    savepath=(args.savepath, 'dataset_config.pkl'),
    env=args.dataset,
    horizon=args.horizon,
    normalizer=args.normalizer,
    preprocess_fns=args.preprocess_fns,
    use_padding=args.use_padding,
    max_path_length=args.max_path_length,
)

render_config = utils.Config(
    args.renderer,
    savepath=(args.savepath, 'render_config.pkl'),
    env=args.dataset,
)

dataset = dataset_config()
renderer = render_config()

observation_dim = dataset.observation_dim
action_dim = dataset.action_dim
# Out:
# [ utils/config ] Imported diffuser.datasets:GoalDataset
#
# [utils/config ] Config: <class 'diffuser.datasets.sequence.GoalDataset'>
#     env: maze2d-large-v1
#     horizon: 384
#     max_path_length: 40000
#     normalizer: LimitsNormalizer
#     preprocess_fns: ['maze2d_set_terminals']
#     use_padding: False
#
# [ utils/config ] Saved config to: logs_dit_final_1M/maze2d-large-v1/diffusion/H384_T256/dataset_config.pkl
#
# [ utils/config ] Imported diffuser.utils:Maze2dRenderer
#
# [utils/config ] Config: <class 'diffuser.utils.rendering.Maze2dRenderer'>
#     env: maze2d-large-v1
#
# [ utils/config ] Saved config to: logs_dit_final_1M/maze2d-large-v1/diffusion/H384_T256/render_config.pkl
# load datafile: 100%|██████████| 8/8 [00:01<00:00,  7.05it/s]
# [ utils/preprocessing ] Segmented maze2d-large-v1 | 1061 paths | min length: 67 | max length: 30470
# [ datasets/buffer ] Finalized replay buffer | 1062 episodes
# [ datasets/buffer ] Fields:
#     actions: (1062, 40000, 2)
#     infos/goal: (1062, 40000, 2)
#     infos/qpos: (1062, 40000, 2)
#     infos/qvel: (1062, 40000, 2)
#     observations: (1062, 40000, 4)
#     rewards: (1062, 40000, 1)
#     terminals: (1062, 40000, 1)
#     timeouts: (1062, 40000, 1)
#     next_observations: (1062, 40000, 4)
#     normed_observations: (1062, 40000, 4)
#     normed_actions: (1062, 40000, 2)

# %%
#-----------------------------------------------------------------------------#
#------------------------------ model & trainer ------------------------------#
#-----------------------------------------------------------------------------#

diffusion_config = utils.Config(
    args.diffusion,
    savepath=(args.savepath, 'diffusion_config.pkl'),
    horizon=args.horizon,
    observation_dim=observation_dim,
    action_dim=action_dim,
    n_timesteps=args.n_diffusion_steps,
    loss_type=args.loss_type,
    clip_denoised=args.clip_denoised,
    predict_epsilon=args.predict_epsilon,
    ## loss weighting
    action_weight=args.action_weight,
    loss_weights=args.loss_weights,
    loss_discount=args.loss_discount,
    device=args.device,
)

trainer_config = utils.Config(
    utils.Trainer,
    savepath=(args.savepath, 'trainer_config.pkl'),
    train_batch_size=args.batch_size,
    train_lr=args.learning_rate,
    gradient_accumulate_every=args.gradient_accumulate_every,
    ema_decay=args.ema_decay,
    sample_freq=args.sample_freq,
    save_freq=args.save_freq,
    label_freq=int(args.n_train_steps // args.n_saves),
    save_parallel=args.save_parallel,
    results_folder=args.savepath,
    bucket=args.bucket,
    n_reference=args.n_reference,
    n_samples=args.n_samples)
# Out:
# [ utils/config ] Imported diffuser.models:GaussianDiffusion
#
# [utils/config ] Config: <class 'diffuser.models.diffusion.GaussianDiffusion'>
#     action_dim: 2
#     action_weight: 1
#     clip_denoised: True
#     horizon: 384
#     loss_discount: 1
#     loss_type: l2
#     loss_weights: None
#     n_timesteps: 256
#     observation_dim: 4
#     predict_epsilon: False
#
# [ utils/config ] Saved config to: logs_dit_final_1M/maze2d-large-v1/diffusion/H384_T256/diffusion_config.pkl
#
#
# [utils/config ] Config: <class 'diffuser.utils.training.Trainer'>
#     bucket: None
#     ema_decay: 0.995
#     gradient_accumulate_every: 2
#     label_freq: 20000
#     n_reference: 50
#     n_samples: 10
#     results_folder: logs_dit_final_1M/maze2d-large-v1/diffusion/H384_T256
#     sample_freq: 10000
#     save_freq: 5000
#     save_parallel: False
#     train_batch_size: 32
#     train_lr: 0.0002
#
# [ utils/config ] Saved config to: logs_dit_final_1M/maze2d-large-v1/diffusion/H384_T256/trainer_config.pkl

# %%
#-----------------------------------------------------------------------------#
#-------------------------------- instantiate --------------------------------#
#-----------------------------------------------------------------------------#

if 'DiT' in args.model:
    model = LDiT_models[args.model](
        in_channels = observation_dim + action_dim,
        max_in_len = args.horizon,
    )
    model = model.to(device=args.device)
else:
    model_config = utils.Config(
        args.model,
        savepath=(args.savepath, 'model_config.pkl'),
        horizon=args.horizon,
        transition_dim=observation_dim + action_dim,
        cond_dim=observation_dim,
        dim_mults=args.dim_mults,
        device=args.device,
    )
    model = model_config()


diffusion = diffusion_config(model)

trainer = trainer_config(diffusion, dataset, renderer)

# %%
checkpoints = sorted([int(x.split('_')[1].split('.')[0]) for x in os.listdir(trainer.logdir) if x.endswith('.pt')])
# TODO: Change this to 1M
checkpoints = [360000]

# %%
from diffuser.guides.policies import Policy

# %%
print(checkpoints[-1])
trainer.load(checkpoints[-1])
diffusion = trainer.model
# Out:
# 360000

# %%
import diffuser.datasets as datasets
env = datasets.load_environment(args.dataset)

# %%
observation = env.reset()
print(observation)
# Out:
# [ 6.91533664  1.90086368 -0.04659669  0.05104924]

# %%
target = env._target
print(target)
# Out:
# (7, 9)

# %%
cond = {
    diffusion.horizon - 1: np.array([*target, 0, 0]),
}

# %%
## observations for rendering
rollout = [observation.copy()]

# %%
total_reward = 0

# %%
from loguru import logger

# %%
policy = Policy(diffusion, dataset.normalizer)
batch_size = 1

# %%
vis_freq = 10

# %%
for t in range(env.max_episode_steps):

        state = env.state_vector().copy()
        logger.info(f'state: {state}')

        ## can replan if desired, but the open-loop plans are good enough for maze2d
        ## that we really only need to plan once
        if t == 0:
            # logger.info(f'planning at t: {t}')
            cond[0] = observation

            action, samples = policy(cond, batch_size=batch_size)
            actions = samples.actions[0]
            sequence = samples.observations[0]
            # logger.info(f'actions: {actions}')
            # logger.info(f'samples: {samples}')
            # logger.info(f'sequence: {sequence}')
        # pdb.set_trace()

        # ####
        if t < len(sequence) - 1:
            next_waypoint = sequence[t+1]
        else:
            next_waypoint = sequence[-1].copy()
            next_waypoint[2:] = 0
            # pdb.set_trace()
        logger.info(f'next_waypoint: {next_waypoint}')
        ## can use actions or define a simple controller based on state predictions
        action = next_waypoint[:2] - state[:2] + (next_waypoint[2:] - state[2:])
        logger.info(f'action: {action}')
        # pdb.set_trace()
        ####

        # else:
        #     actions = actions[1:]
        #     if len(actions) > 1:
        #         action = actions[0]
        #     else:
        #         # action = np.zeros(2)
        #         action = -state[2:]
        #         pdb.set_trace()



        next_observation, reward, terminal, _ = env.step(action)
        logger.info(f'next_observation: {next_observation}')
        logger.info(f'reward: {reward}')
        logger.info(f'terminal: {terminal}')
        logger.info(f'_: {_}')
        total_reward += reward
        score = env.get_normalized_score(total_reward)
        print(
            f't: {t} | r: {reward:.2f} |  R: {total_reward:.2f} | score: {score:.4f} | ref_max_score: {env.ref_max_score} | ref_min_score: {env.ref_min_score}'
            f'{action}'
        )

        xy = next_observation[:2]
        goal = env.unwrapped._target
        print(f'maze | pos: {xy} | goal: {goal}')

        ## update rollout observations
        rollout.append(next_observation.copy())

        # logger.log(score=score, step=t)

        if terminal:
            break

        observation = next_observation
# Out:
# 2024-06-07 09:04:46.352 | INFO     | __main__:<module>:4 - state: [ 6.91049418  1.90342088 -0.22499396  0.12603058]
#
# 1 / 256 [                                                            ]   0% | 156.6 Hz
# t : 255
#
#
# 2 / 256 [                                                            ]   0% | 167.9 Hz
# t : 254
#
#
# 3 / 256 [                                                            ]   1% | 173.4 Hz
# t : 253
#
#
# 4 / 256 [                                                            ]   1% | 176.3 Hz
# t : 252
#
#
# 5 / 256 [#                                                           ]   1% | 178.2 Hz
# t : 251
#
#
# 6 / 256 [#                                                           ]   2% | 179.8 Hz
# t : 250
#
#
# 7 / 256 [#                                                           ]   2% | 180.8 Hz
# t : 249
#
#
# 8 / 256 [#                                                           ]   3% | 181.8 Hz
# t : 248
#
#
# 9 / 256 [##                                                          ]   3% | 182.3 Hz
# t : 247
#
#
# 10 / 256 [##                                                          ]   3% | 182.8 Hz
# t : 246
#
#
# 11 / 256 [##                                                          ]   4% | 183.0 Hz
# t : 245
#
#
# 12 / 256 [##                                                          ]   4% | 183.4 Hz
# t : 244
#
#
# 13 / 256 [###                                                         ]   5% | 183.7 Hz
# t : 243
#
#
# 14 / 256 [###                                                         ]   5% | 183.8 Hz
# t : 242
#
#
# 15 / 256 [###                                                         ]   5% | 184.1 Hz
# t : 241
#
#
# 16 / 256 [###                                                         ]   6% | 184.2 Hz
# t : 240
#
#
# 17 / 256 [###                                                         ]   6% | 184.3 Hz
# t : 239
#
#
# 18 / 256 [####                                                        ]   7% | 184.4 Hz
# t : 238
#
#
# 19 / 256 [####                                                        ]   7% | 184.5 Hz
# t : 237
#
#
# 20 / 256 [####                                                        ]   7% | 184.7 Hz
# t : 236
#
#
# 21 / 256 [####                                                        ]   8% | 184.8 Hz
# t : 235
#
#
# 22 / 256 [#####                                                       ]   8% | 184.7 Hz
# t : 234
#
#
# 23 / 256 [#####                                                       ]   8% | 184.7 Hz
# t : 233
#
#
# 24 / 256 [#####                                                       ]   9% | 184.8 Hz
# t : 232
#
#
# 25 / 256 [#####                                                       ]   9% | 184.8 Hz
# t : 231
#
#
# 26 / 256 [######                                                      ]  10% | 185.1 Hz
# t : 230
#
#
# 27 / 256 [######                                                      ]  10% | 185.1 Hz
# t : 229
#
#
# 28 / 256 [######                                                      ]  10% | 185.2 Hz
# t : 228
#
#
# 29 / 256 [######                                                      ]  11% | 185.2 Hz
# t : 227
#
#
# 30 / 256 [#######                                                     ]  11% | 185.3 Hz
# t : 226
#
#
# 31 / 256 [#######                                                     ]  12% | 185.4 Hz
# t : 225
#
#
# 32 / 256 [#######                                                     ]  12% | 185.4 Hz
# t : 224
#
#
# 33 / 256 [#######                                                     ]  12% | 185.6 Hz
# t : 223
#
#
# 34 / 256 [#######                                                     ]  13% | 185.7 Hz
# t : 222
#
#
# 35 / 256 [########                                                    ]  13% | 185.6 Hz
# t : 221
#
#
# 36 / 256 [########                                                    ]  14% | 185.7 Hz
# t : 220
#
#
# 37 / 256 [########                                                    ]  14% | 185.7 Hz
# t : 219
#
#
# 38 / 256 [########                                                    ]  14% | 185.3 Hz
# t : 218
#
#
# 39 / 256 [#########                                                   ]  15% | 185.2 Hz
# t : 217
#
#
# 40 / 256 [#########                                                   ]  15% | 185.2 Hz
# t : 216
#
#
# 41 / 256 [#########                                                   ]  16% | 185.3 Hz
# t : 215
#
#
# 42 / 256 [#########                                                   ]  16% | 185.3 Hz
# t : 214
#
#
# 43 / 256 [##########                                                  ]  16% | 185.4 Hz
# t : 213
#
#
# 44 / 256 [##########                                                  ]  17% | 185.3 Hz
# t : 212
#
#
# 45 / 256 [##########                                                  ]  17% | 185.3 Hz
# t : 211
#
#
# 46 / 256 [##########                                                  ]  17% | 185.4 Hz
# t : 210
#
#
# 47 / 256 [###########                                                 ]  18% | 185.5 Hz
# t : 209
#
#
# 48 / 256 [###########                                                 ]  18% | 185.6 Hz
# t : 208
#
#
# 49 / 256 [###########                                                 ]  19% | 185.6 Hz
# t : 207
#
#
# 50 / 256 [###########                                                 ]  19% | 185.7 Hz
# t : 206
#
#
# 51 / 256 [###########                                                 ]  19% | 185.7 Hz
# t : 205
#
#
# 52 / 256 [############                                                ]  20% | 185.8 Hz
# t : 204
#
#
# 53 / 256 [############                                                ]  20% | 185.8 Hz
# t : 203
#
#
# 54 / 256 [############                                                ]  21% | 185.9 Hz
# t : 202
#
#
# 55 / 256 [############                                                ]  21% | 185.8 Hz
# t : 201
#
#
# 56 / 256 [#############                                               ]  21% | 185.8 Hz
# t : 200
#
#
# 57 / 256 [#############                                               ]  22% | 185.9 Hz
# t : 199
#
#
# 58 / 256 [#############                                               ]  22% | 185.9 Hz
# t : 198
#
#
# 59 / 256 [#############                                               ]  23% | 186.0 Hz
# t : 197
#
#
# 60 / 256 [##############                                              ]  23% | 186.0 Hz
# t : 196
#
#
# 61 / 256 [##############                                              ]  23% | 186.0 Hz
# t : 195
#
#
# 62 / 256 [##############                                              ]  24% | 186.0 Hz
# t : 194
#
#
# 63 / 256 [##############                                              ]  24% | 186.0 Hz
# t : 193
#
#
# 64 / 256 [###############                                             ]  25% | 186.1 Hz
# t : 192
#
#
# 65 / 256 [###############                                             ]  25% | 186.1 Hz
# t : 191
#
#
# 66 / 256 [###############                                             ]  25% | 186.2 Hz
# t : 190
#
#
# 67 / 256 [###############                                             ]  26% | 186.2 Hz
# t : 189
#
#
# 68 / 256 [###############                                             ]  26% | 186.3 Hz
# t : 188
#
#
# 69 / 256 [################                                            ]  26% | 186.3 Hz
# t : 187
#
#
# 70 / 256 [################                                            ]  27% | 186.4 Hz
# t : 186
#
#
# 71 / 256 [################                                            ]  27% | 186.4 Hz
# t : 185
#
#
# 72 / 256 [################                                            ]  28% | 186.4 Hz
# t : 184
#
#
# 73 / 256 [#################                                           ]  28% | 186.4 Hz
# t : 183
#
#
# 74 / 256 [#################                                           ]  28% | 186.4 Hz
# t : 182
#
#
# 75 / 256 [#################                                           ]  29% | 186.4 Hz
# t : 181
#
#
# 76 / 256 [#################                                           ]  29% | 186.1 Hz
# t : 180
#
#
# 77 / 256 [##################                                          ]  30% | 186.0 Hz
# t : 179
#
#
# 78 / 256 [##################                                          ]  30% | 185.8 Hz
# t : 178
#
#
# 79 / 256 [##################                                          ]  30% | 185.8 Hz
# t : 177
#
#
# 80 / 256 [##################                                          ]  31% | 185.8 Hz
# t : 176
#
#
# 81 / 256 [##################                                          ]  31% | 185.9 Hz
# t : 175
#
#
# 82 / 256 [###################                                         ]  32% | 185.9 Hz
# t : 174
#
#
# 83 / 256 [###################                                         ]  32% | 185.9 Hz
# t : 173
#
#
# 84 / 256 [###################                                         ]  32% | 185.9 Hz
# t : 172
#
#
# 85 / 256 [###################                                         ]  33% | 186.0 Hz
# t : 171
#
#
# 86 / 256 [####################                                        ]  33% | 186.0 Hz
# t : 170
#
#
# 87 / 256 [####################                                        ]  33% | 186.0 Hz
# t : 169
#
#
# 88 / 256 [####################                                        ]  34% | 185.9 Hz
# t : 168
#
#
# 89 / 256 [####################                                        ]  34% | 185.7 Hz
# t : 167
#
#
# 90 / 256 [#####################                                       ]  35% | 185.5 Hz
# t : 166
#
#
# 91 / 256 [#####################                                       ]  35% | 185.2 Hz
# t : 165
#
#
# 92 / 256 [#####################                                       ]  35% | 184.9 Hz
# t : 164
#
#
# 93 / 256 [#####################                                       ]  36% | 184.6 Hz
# t : 163
#
#
# 94 / 256 [######################                                      ]  36% | 184.6 Hz
# t : 162
#
#
# 95 / 256 [######################                                      ]  37% | 184.6 Hz
# t : 161
#
#
# 96 / 256 [######################                                      ]  37% | 184.5 Hz
# t : 160
#
#
# 97 / 256 [######################                                      ]  37% | 184.6 Hz
# t : 159
#
#
# 98 / 256 [######################                                      ]  38% | 184.6 Hz
# t : 158
#
#
# 99 / 256 [#######################                                     ]  38% | 184.7 Hz
# t : 157
#
#
# 100 / 256 [#######################                                     ]  39% | 0.0 Hz
# t : 156
#
#
# 101 / 256 [#######################                                     ]  39% | 186.0 Hz
# t : 155
#
#
# 102 / 256 [#######################                                     ]  39% | 188.3 Hz
# t : 154
#
#
# 103 / 256 [########################                                    ]  40% | 189.0 Hz
# t : 153
#
#
# 104 / 256 [########################                                    ]  40% | 189.4 Hz
# t : 152
#
#
# 105 / 256 [########################                                    ]  41% | 189.4 Hz
# t : 151
#
#
# 106 / 256 [########################                                    ]  41% | 189.8 Hz
# t : 150
#
#
# 107 / 256 [#########################                                   ]  41% | 189.4 Hz
# t : 149
#
#
# 108 / 256 [#########################                                   ]  42% | 188.7 Hz
# t : 148
#
#
# 109 / 256 [#########################                                   ]  42% | 188.2 Hz
# t : 147
#
#
# 110 / 256 [#########################                                   ]  42% | 188.2 Hz
# t : 146
#
#
# 111 / 256 [##########################                                  ]  43% | 188.4 Hz
# t : 145
#
#
# 112 / 256 [##########################                                  ]  43% | 186.9 Hz
# t : 144
#
#
# 113 / 256 [##########################                                  ]  44% | 183.8 Hz
# t : 143
#
#
# 114 / 256 [##########################                                  ]  44% | 182.0 Hz
# t : 142
#
#
# 115 / 256 [##########################                                  ]  44% | 182.3 Hz
# t : 141
#
#
# 116 / 256 [###########################                                 ]  45% | 182.6 Hz
# t : 140
#
#
# 117 / 256 [###########################                                 ]  45% | 182.9 Hz
# t : 139
#
#
# 118 / 256 [###########################                                 ]  46% | 183.2 Hz
# t : 138
#
#
# 119 / 256 [###########################                                 ]  46% | 183.5 Hz
# t : 137
#
#
# 120 / 256 [############################                                ]  46% | 183.8 Hz
# t : 136
#
#
# 121 / 256 [############################                                ]  47% | 183.9 Hz
# t : 135
#
#
# 122 / 256 [############################                                ]  47% | 183.9 Hz
# t : 134
#
#
# 123 / 256 [############################                                ]  48% | 184.0 Hz
# t : 133
#
#
# 124 / 256 [#############################                               ]  48% | 184.0 Hz
# t : 132
#
#
# 125 / 256 [#############################                               ]  48% | 184.1 Hz
# t : 131
#
#
# 126 / 256 [#############################                               ]  49% | 184.2 Hz
# t : 130
#
#
# 127 / 256 [#############################                               ]  49% | 184.2 Hz
# t : 129
#
#
# 128 / 256 [##############################                              ]  50% | 184.4 Hz
# t : 128
#
#
# 129 / 256 [##############################                              ]  50% | 184.4 Hz
# t : 127
#
#
# 130 / 256 [##############################                              ]  50% | 184.5 Hz
# t : 126
#
#
# 131 / 256 [##############################                              ]  51% | 184.6 Hz
# t : 125
#
#
# 132 / 256 [##############################                              ]  51% | 184.8 Hz
# t : 124
#
#
# 133 / 256 [###############################                             ]  51% | 185.0 Hz
# t : 123
#
#
# 134 / 256 [###############################                             ]  52% | 185.0 Hz
# t : 122
#
#
# 135 / 256 [###############################                             ]  52% | 185.2 Hz
# t : 121
#
#
# 136 / 256 [###############################                             ]  53% | 185.3 Hz
# t : 120
#
#
# 137 / 256 [################################                            ]  53% | 185.4 Hz
# t : 119
#
#
# 138 / 256 [################################                            ]  53% | 185.5 Hz
# t : 118
#
#
# 139 / 256 [################################                            ]  54% | 185.4 Hz
# t : 117
#
#
# 140 / 256 [################################                            ]  54% | 185.5 Hz
# t : 116
#
#
# 141 / 256 [#################################                           ]  55% | 185.6 Hz
# t : 115
#
#
# 142 / 256 [#################################                           ]  55% | 185.7 Hz
# t : 114
#
#
# 143 / 256 [#################################                           ]  55% | 185.7 Hz
# t : 113
#
#
# 144 / 256 [#################################                           ]  56% | 185.8 Hz
# t : 112
#
#
# 145 / 256 [#################################                           ]  56% | 185.9 Hz
# t : 111
#
#
# 146 / 256 [##################################                          ]  57% | 186.1 Hz
# t : 110
#
#
# 147 / 256 [##################################                          ]  57% | 185.9 Hz
# t : 109
#
#
# 148 / 256 [##################################                          ]  57% | 185.9 Hz
# t : 108
#
#
# 149 / 256 [##################################                          ]  58% | 185.9 Hz
# t : 107
#
#
# 150 / 256 [###################################                         ]  58% | 186.0 Hz
# t : 106
#
#
# 151 / 256 [###################################                         ]  58% | 185.6 Hz
# t : 105
#
#
# 152 / 256 [###################################                         ]  59% | 185.6 Hz
# t : 104
#
#
# 153 / 256 [###################################                         ]  59% | 185.7 Hz
# t : 103
#
#
# 154 / 256 [####################################                        ]  60% | 185.6 Hz
# t : 102
#
#
# 155 / 256 [####################################                        ]  60% | 185.5 Hz
# t : 101
#
#
# 156 / 256 [####################################                        ]  60% | 185.6 Hz
# t : 100
#
#
# 157 / 256 [####################################                        ]  61% | 185.7 Hz
# t : 99
#
#
# 158 / 256 [#####################################                       ]  61% | 185.7 Hz
# t : 98
#
#
# 159 / 256 [#####################################                       ]  62% | 185.7 Hz
# t : 97
#
#
# 160 / 256 [#####################################                       ]  62% | 185.8 Hz
# t : 96
#
#
# ...
# 2024-06-07 09:04:52.160 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.161 | INFO     | __main__:<module>:30 - action: [6.61169534e-05 6.80149796e+00]
# 2024-06-07 09:04:52.162 | INFO     | __main__:<module>:46 - next_observation: [ 7.00191908e+00  2.19850204e+00 -1.98452462e-03  6.29734138e-15]
# 2024-06-07 09:04:52.163 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.164 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.165 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.166 | INFO     | __main__:<module>:4 - state: [ 7.00191908e+00  2.19850204e+00 -1.98452462e-03  6.29734138e-15]
# 2024-06-07 09:04:52.167 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.168 | INFO     | __main__:<module>:30 - action: [6.54402361e-05 6.80149796e+00]
# 2024-06-07 09:04:52.169 | INFO     | __main__:<module>:46 - next_observation: [ 7.00189944e+00  2.19850204e+00 -1.96421270e-03  6.29734138e-15]
# 2024-06-07 09:04:52.170 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.171 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.171 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.172 | INFO     | __main__:<module>:4 - state: [ 7.00189944e+00  2.19850204e+00 -1.96421270e-03  6.29734138e-15]
# 2024-06-07 09:04:52.173 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.174 | INFO     | __main__:<module>:30 - action: [6.47704451e-05 6.80149796e+00]
# 2024-06-07 09:04:52.174 | INFO     | __main__:<module>:46 - next_observation: [ 7.00188000e+00  2.19850204e+00 -1.94410868e-03  6.29734138e-15]
# 2024-06-07 09:04:52.176 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.176 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.177 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.178 | INFO     | __main__:<module>:4 - state: [ 7.00188000e+00  2.19850204e+00 -1.94410868e-03  6.29734138e-15]
# 2024-06-07 09:04:52.179 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.179 | INFO     | __main__:<module>:30 - action: [6.41075095e-05 6.80149796e+00]
# 2024-06-07 09:04:52.180 | INFO     | __main__:<module>:46 - next_observation: [ 7.00186076e+00  2.19850204e+00 -1.92421042e-03  6.29734138e-15]
# 2024-06-07 09:04:52.181 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.181 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.182 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.183 | INFO     | __main__:<module>:4 - state: [ 7.00186076e+00  2.19850204e+00 -1.92421042e-03  6.29734138e-15]
# 2024-06-07 09:04:52.184 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.184 | INFO     | __main__:<module>:30 - action: [6.34513592e-05 6.80149796e+00]
# 2024-06-07 09:04:52.185 | INFO     | __main__:<module>:46 - next_observation: [ 7.00184171e+00  2.19850204e+00 -1.90451583e-03  6.29734138e-15]
# 2024-06-07 09:04:52.186 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.186 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.186 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.187 | INFO     | __main__:<module>:4 - state: [ 7.00184171e+00  2.19850204e+00 -1.90451583e-03  6.29734138e-15]
# 2024-06-07 09:04:52.188 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.188 | INFO     | __main__:<module>:30 - action: [6.28019247e-05 6.80149796e+00]
# 2024-06-07 09:04:52.191 | INFO     | __main__:<module>:46 - next_observation: [ 7.00182286e+00  2.19850204e+00 -1.88502281e-03  6.29734138e-15]
# 2024-06-07 09:04:52.191 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.192 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.193 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.194 | INFO     | __main__:<module>:4 - state: [ 7.00182286e+00  2.19850204e+00 -1.88502281e-03  6.29734138e-15]
# 2024-06-07 09:04:52.195 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.196 | INFO     | __main__:<module>:30 - action: [6.21591372e-05 6.80149796e+00]
# 2024-06-07 09:04:52.197 | INFO     | __main__:<module>:46 - next_observation: [ 7.00180421e+00  2.19850204e+00 -1.86572931e-03  6.29734138e-15]
# 2024-06-07 09:04:52.199 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.199 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.200 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.201 | INFO     | __main__:<module>:4 - state: [ 7.00180421e+00  2.19850204e+00 -1.86572931e-03  6.29734138e-15]
# 2024-06-07 09:04:52.202 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.202 | INFO     | __main__:<module>:30 - action: [6.15229288e-05 6.80149796e+00]
# 2024-06-07 09:04:52.204 | INFO     | __main__:<module>:46 - next_observation: [ 7.00178574e+00  2.19850204e+00 -1.84663328e-03  6.29734138e-15]
# 2024-06-07 09:04:52.205 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.205 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.206 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.207 | INFO     | __main__:<module>:4 - state: [ 7.00178574e+00  2.19850204e+00 -1.84663328e-03  6.29734138e-15]
# 2024-06-07 09:04:52.209 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.209 | INFO     | __main__:<module>:30 - action: [6.08932321e-05 6.80149796e+00]
# 2024-06-07 09:04:52.211 | INFO     | __main__:<module>:46 - next_observation: [ 7.00176746e+00  2.19850204e+00 -1.82773270e-03  6.29734138e-15]
# 2024-06-07 09:04:52.211 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.212 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.212 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.213 | INFO     | __main__:<module>:4 - state: [ 7.00176746e+00  2.19850204e+00 -1.82773270e-03  6.29734138e-15]
# 2024-06-07 09:04:52.214 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.214 | INFO     | __main__:<module>:30 - action: [6.02699804e-05 6.80149796e+00]
# 2024-06-07 09:04:52.215 | INFO     | __main__:<module>:46 - next_observation: [ 7.00174937e+00  2.19850204e+00 -1.80902558e-03  6.29734138e-15]
# 2024-06-07 09:04:52.217 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.217 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.218 | INFO     | __main__:<module>:49 - _: {}
# 2024-06-07 09:04:52.220 | INFO     | __main__:<module>:4 - state: [ 7.00174937e+00  2.19850204e+00 -1.80902558e-03  6.29734138e-15]
# 2024-06-07 09:04:52.221 | INFO     | __main__:<module>:27 - next_waypoint: [7. 9. 0. 0.]
# 2024-06-07 09:04:52.222 | INFO     | __main__:<module>:30 - action: [5.96531077e-05 6.80149796e+00]
# 2024-06-07 09:04:52.223 | INFO     | __main__:<module>:46 - next_observation: [ 7.00173147e+00  2.19850204e+00 -1.79050992e-03  6.29734138e-15]
# 2024-06-07 09:04:52.223 | INFO     | __main__:<module>:47 - reward: 0.0
# 2024-06-07 09:04:52.224 | INFO     | __main__:<module>:48 - terminal: False
# 2024-06-07 09:04:52.224 | INFO     | __main__:<module>:49 - _: {}
# t: 767 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[8.29102653e-05 6.80149796e+00]
# maze | pos: [7.00240652 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 768 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[8.20616658e-05 6.80149796e+00]
# maze | pos: [7.00238189 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 769 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[8.12217519e-05 6.80149796e+00]
# maze | pos: [7.00235751 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 770 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[8.03904347e-05 6.80149796e+00]
# maze | pos: [7.00233338 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 771 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.95676261e-05 6.80149796e+00]
# maze | pos: [7.0023095  2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 772 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.87532390e-05 6.80149796e+00]
# maze | pos: [7.00228586 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 773 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.79471874e-05 6.80149796e+00]
# maze | pos: [7.00226246 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 774 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.71493858e-05 6.80149796e+00]
# maze | pos: [7.00223931 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 775 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.63597499e-05 6.80149796e+00]
# maze | pos: [7.00221639 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 776 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.55781959e-05 6.80149796e+00]
# maze | pos: [7.0021937  2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 777 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.48046414e-05 6.80149796e+00]
# maze | pos: [7.00217125 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 778 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.40390042e-05 6.80149796e+00]
# maze | pos: [7.00214903 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 779 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.32812035e-05 6.80149796e+00]
# maze | pos: [7.00212703 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 780 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.25311590e-05 6.80149796e+00]
# maze | pos: [7.00210526 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 781 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.17887913e-05 6.80149796e+00]
# maze | pos: [7.00208371 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 782 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.10540219e-05 6.80149796e+00]
# maze | pos: [7.00206239 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 783 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[7.03267729e-05 6.80149796e+00]
# maze | pos: [7.00204128 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 784 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.96069675e-05 6.80149796e+00]
# maze | pos: [7.00202038 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 785 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.88945293e-05 6.80149796e+00]
# maze | pos: [7.00199971 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 786 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.81893831e-05 6.80149796e+00]
# maze | pos: [7.00197924 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 787 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.74914542e-05 6.80149796e+00]
# maze | pos: [7.00195898 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 788 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.68006686e-05 6.80149796e+00]
# maze | pos: [7.00193893 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 789 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.61169534e-05 6.80149796e+00]
# maze | pos: [7.00191908 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 790 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.54402361e-05 6.80149796e+00]
# maze | pos: [7.00189944 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 791 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.47704451e-05 6.80149796e+00]
# maze | pos: [7.00188    2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 792 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.41075095e-05 6.80149796e+00]
# maze | pos: [7.00186076 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 793 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.34513592e-05 6.80149796e+00]
# maze | pos: [7.00184171 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 794 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.28019247e-05 6.80149796e+00]
# maze | pos: [7.00182286 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 795 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.21591372e-05 6.80149796e+00]
# maze | pos: [7.00180421 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 796 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.15229288e-05 6.80149796e+00]
# maze | pos: [7.00178574 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 797 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.08932321e-05 6.80149796e+00]
# maze | pos: [7.00176746 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 798 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[6.02699804e-05 6.80149796e+00]
# maze | pos: [7.00174937 2.19850204] | goal: (7, 9)
# sparse, mess it up
# 0.0, sparse, sparse is getting called
# 0.0, sparse, ... is getting called
# t: 799 | r: 0.00 |  R: 0.00 | score: -0.0251 | ref_max_score: 273.99 | ref_min_score: 6.7[5.96531077e-05 6.80149796e+00]
# maze | pos: [7.00173147 2.19850204] | goal: (7, 9)
